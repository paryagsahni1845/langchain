# %% [markdown]
# ## Ollama
# Ollama is an open-source platform that lets you run large language models (LLMs) locally on your own machine.
# You can download models like LLaMA, Mistral, Gemma, Phi, etc., and interact with them via a simple terminal command ollama run model_name.
# Basically, it’s like a local ChatGPT runner, but instead of depending on cloud APIs, you host the models yourself.
# lightweight

# %%
from langchain_community.embeddings import OllamaEmbeddings

# %%
embeddings =(
    OllamaEmbeddings(model= "gemma:2b")
)
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_4540\1719316060.py:2: LangChainDeprecationWarning: The class `OllamaEmbeddings` was deprecated in LangChain 0.3.1 and will be removed in 1.0.0. An updated version of the class exists in the :class:`~langchain-ollama package and should be used instead. To use it run `pip install -U :class:`~langchain-ollama` and import as `from :class:`~langchain_ollama import OllamaEmbeddings``.
#   OllamaEmbeddings(model= "gemma:2b")

# %%
embeddings
# Out:
# OllamaEmbeddings(base_url='http://localhost:11434', model='gemma:2b', embed_instruction='passage: ', query_instruction='query: ', mirostat=None, mirostat_eta=None, mirostat_tau=None, num_ctx=None, num_gpu=None, num_thread=None, repeat_last_n=None, repeat_penalty=None, temperature=None, stop=None, tfs_z=None, top_k=None, top_p=None, show_progress=False, headers=None, model_kwargs=None)

# %%
r1 = embeddings.embed_documents(
    [
        "Artificial intelligence is transforming industries by automating tasks and improving decision-making.","Machine learning models learn patterns from data and can make predictions on unseen inputs."
    ]
)

# %%
r1
# Out:
# [[-1.7259145975112915,
#   -1.7234206199645996,
#   -1.7181198596954346,
#   2.5105090141296387,
#   1.5456209182739258,
#   0.9745509624481201,
#   0.9718255400657654,
#   -1.120043158531189,
#   -0.4711494743824005,
#   -0.5320821404457092,
#   1.8407942056655884,
#   0.9846799969673157,
#   0.2679533064365387,
#   0.1559424251317978,
#   0.13486014306545258,
#   0.05246971547603607,
#   10.191062927246094,
#   -0.3737707734107971,
#   0.35002705454826355,
#   0.37105751037597656,
#   -0.23339931666851044,
#   -0.1350613236427307,
#   0.5651431083679199,
#   0.48359718918800354,
#   -0.7897881269454956,
#   1.0298181772232056,
#   1.299176812171936,
#   0.32118284702301025,
#   -0.4888792335987091,
#   -2.2225494384765625,
#   -1.0822725296020508,
#   0.23965522646903992,
#   -0.26495617628097534,
#   -0.24028469622135162,
#   -1.5444625616073608,
#   -0.07458285987377167,
#   -0.272826224565506,
#   -1.3735800981521606,
#   0.7214282751083374,
#   -1.9493285417556763,
# ...

# %%
len(r1[0])
# Out:
# 2048

# %%
embeddings.embed_query("Machine learning models learn patterns from data and can make predictions on unseen inputs.")
# Out:
# [-0.47331899404525757,
#  -1.1000123023986816,
#  0.10875443369150162,
#  1.9201325178146362,
#  0.6992208957672119,
#  0.9707450866699219,
#  1.3323113918304443,
#  0.19504261016845703,
#  1.5624836683273315,
#  -0.32161107659339905,
#  0.475336492061615,
#  1.3845703601837158,
#  -0.35103628039360046,
#  0.8092408776283264,
#  0.08174563199281693,
#  0.01746547408401966,
#  10.318069458007812,
#  0.30327728390693665,
#  0.46609845757484436,
#  -0.7436553835868835,
#  1.2514907121658325,
#  -0.27429768443107605,
#  0.022878695279359818,
#  0.6892807483673096,
#  -2.7321653366088867,
#  -0.2316093146800995,
#  0.10638955235481262,
#  0.6716175079345703,
#  -1.4461636543273926,
#  -2.1582260131835938,
#  -0.7406821250915527,
#  1.2855182886123657,
#  -0.029808277264237404,
#  -0.06049158424139023,
#  -1.5415276288986206,
#  0.5361461639404297,
#  0.27144989371299744,
#  -0.513791561126709,
#  1.2802238464355469,
#  -0.9064890742301941,
#  -0.640720009803772,
#  -1.0155616998672485,
# ...
